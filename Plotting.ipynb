# %%
import yt
print(yt.__version__) # 3.6.0 or higher
# Out:
# 3.6.0

# %% [markdown]
# ## Plot a single image

# %%
datfile = 'output/cart_T_HR_1163.dat'
ds = yt.load(datfile)
# Out:
# yt : [INFO     ] 2020-10-20 22:08:07,203 Parameters: current_time              = 11.59429688050754
# yt : [INFO     ] 2020-10-20 22:08:07,204 Parameters: domain_dimensions         = [256 256   1]
# yt : [INFO     ] 2020-10-20 22:08:07,204 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-10-20 22:08:07,205 Parameters: domain_right_edge         = [2. 1. 1.]
# yt : [INFO     ] 2020-10-20 22:08:07,205 Parameters: cosmological_simulation   = 0

# %%
p = yt.plot_2d(ds, 'm1')
p.show()
# Out:
# yt : [WARNING  ] 2020-10-20 22:08:08,513 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2020-10-20 22:08:08,698 xlim = 0.000000 2.000000
# yt : [INFO     ] 2020-10-20 22:08:08,698 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-10-20 22:08:08,699 xlim = 0.000000 2.000000
# yt : [INFO     ] 2020-10-20 22:08:08,699 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-10-20 22:08:08,704 Making a fixed resolution buffer of (('amrvac', 'm1')) 800 by 800
# yt : [WARNING  ] 2020-10-20 22:08:08,774 Plot image for field ('amrvac', 'm1') has both positive and negative values. Min = -0.530610, Max = 1.947585.
# yt : [WARNING  ] 2020-10-20 22:08:08,774 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
